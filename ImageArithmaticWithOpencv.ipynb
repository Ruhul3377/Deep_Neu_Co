# %%
# !pip insgtall opencv-pyhton

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
def plt_imshow(title, image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.title("cat_Image.jpg")
    plt.grid(True)
    plt.show()

# %%
args = {"image":"cat_Image.jpg"}

# %%
# img = cv2.imread("dog_image.jpg")
# img.shape

# %%
# cv2.imread("dog_Image.jpg")

# %%
imageAddCustomValue = cv2.add(np.uint8([200]), np.uint8([100]))
imageSubtractCustomValue = cv2.subtract(np.uint8([50]), np.uint8([100]))

# %%
print("Image Maximum value of 255 {}".format(imageAddCustomValue))
print("Image Minimum value of 255 {}".format(imageSubtractCustomValue))
# Out:
# Image Maximum value of 255 [[255]]
# Image Minimum value of 255 [[0]]

# %%
imageAddCustomValue =np.uint8([200])+ np.uint8([100])
imageSubtractCustomValue = np.uint8([50])- np.uint8([100])

# %%
print("Image Maximum value of 255 {}".format(imageAddCustomValue))
print("Image Minimum value of 255 {}".format(imageSubtractCustomValue))
# Out:
# Image Maximum value of 255 [44]
# Image Minimum value of 255 [206]

# %%
img = cv2.imread(args['image'])
img.shape
# Out:
# (1200, 1600, 3)

# %%
img
# Out:
# array([[[ 95,  97,  97],
#         [ 95,  97,  97],
#         [ 95,  97,  97],
#         ...,
#         [100, 101,  99],
#         [ 99, 100,  98],
#         [ 99, 100,  98]],
#
#        [[ 95,  97,  97],
#         [ 95,  97,  97],
#         [ 95,  97,  97],
#         ...,
#         [102, 103, 101],
#         [102, 103, 101],
#         [103, 104, 102]],
#
#        [[ 94,  96,  96],
#         [ 94,  96,  96],
#         [ 94,  96,  96],
#         ...,
#         [102, 103, 101],
#         [102, 103, 101],
#         [102, 103, 101]],
#
#        ...,
#
#        [[ 65,  65,  65],
#         [ 65,  65,  65],
#         [ 66,  66,  66],
#         ...,
#         [ 40,  32,  25],
#         [ 43,  34,  25],
#         [ 41,  32,  23]],
#
#        [[ 65,  65,  65],
#         [ 65,  65,  65],
#         [ 66,  66,  66],
#         ...,
#         [ 39,  31,  24],
#         [ 41,  31,  24],
#         [ 36,  26,  19]],
#
#        [[ 65,  65,  65],
#         [ 65,  65,  65],
#         [ 66,  66,  66],
# ...

# %%
m = np.ones(img.shape, dtype=np.uint8) *100

# %%
m
# Out:
# array([[[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        ...,
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
# ...

# %%
add = cv2.add(img, m)

# %%
add = cv2.add(img, m)
plt_imshow("Added value", add)
